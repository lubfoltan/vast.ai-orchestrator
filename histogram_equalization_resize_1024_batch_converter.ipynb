# %%
from pathlib import Path
from PIL import Image, ImageOps
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

print("Knižnice sú načítané.")
# Out:
# Knižnice sú načítané.

# %%
input_dir = Path(r"D:\hsu_semestralka\dataset_merged")
output_dir = Path(r"D:\hsu_semestralka\dataset_merged_histogram_equalization_512")


valid_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}


save_as_rgb = True


target_size = (512, 512)


jpeg_quality = 95


overwrite_existing = True


preview_count = 6

print("Input:", input_dir)
print("Output:", output_dir)
print("Target size:", target_size)
# Out:
# Input: D:\hsu_semestralka\dataset_merged
# Output: D:\hsu_semestralka\dataset_merged_histogram_equalization_512
# Target size: (512, 512)

# %%
def check_paths(input_dir: Path, output_dir: Path):

    if not input_dir.exists():
        raise FileNotFoundError(f"Vstupný priečinok neexistuje: {input_dir}")

    input_resolved = input_dir.resolve()
    output_resolved = output_dir.resolve()

    if input_resolved == output_resolved:
        raise ValueError("input_dir a output_dir nesmú byť rovnaké.")

    try:
        output_resolved.relative_to(input_resolved)
        raise ValueError(
            "output_dir je vo vnútri input_dir. "
            "Daj výstupný priečinok mimo vstupného datasetu."
        )
    except ValueError as e:
        if "output_dir je vo vnútri input_dir" in str(e):
            raise

    output_dir.mkdir(parents=True, exist_ok=True)


def apply_histogram_equalization(image: Image.Image, save_as_rgb=True) -> Image.Image:

    gray = image.convert("L")
    equalized = ImageOps.equalize(gray)

    if save_as_rgb:
        equalized = equalized.convert("RGB")

    return equalized


def resize_to_target(image: Image.Image, target_size=(512, 512)) -> Image.Image:


    return image.resize(target_size, Image.Resampling.LANCZOS)


def process_one_image(image_path: Path) -> Image.Image:

    img = Image.open(image_path).convert("RGB")

    hist_eq_img = apply_histogram_equalization(
        img,
        save_as_rgb=save_as_rgb
    )

    resized = resize_to_target(hist_eq_img, target_size=target_size)

    return resized


def save_image(img: Image.Image, output_path: Path, jpeg_quality=95):

    output_path.parent.mkdir(parents=True, exist_ok=True)

    suffix = output_path.suffix.lower()

    if suffix in {".jpg", ".jpeg"}:
        img.save(output_path, quality=jpeg_quality)
    else:
        img.save(output_path)


print("Funkcie sú pripravené.")
# Out:
# Funkcie sú pripravené.

# %%
check_paths(input_dir, output_dir)

image_paths = [
    path for path in input_dir.rglob("*")
    if path.is_file() and path.suffix.lower() in valid_extensions
]

images_by_folder = defaultdict(list)

for image_path in image_paths:
    images_by_folder[image_path.parent].append(image_path)

print(f"Počet nájdených obrázkov: {len(image_paths)}")
print(f"Počet priečinkov s obrázkami: {len(images_by_folder)}")
print("-" * 70)

for folder_path, folder_images in sorted(images_by_folder.items()):
    relative_folder = folder_path.relative_to(input_dir)
    print(f"{relative_folder}: {len(folder_images)} obrázkov")
# Out:
# Počet nájdených obrázkov: 14386
# Počet priečinkov s obrázkami: 2
# ----------------------------------------------------------------------
# NORMAL: 5848 obrázkov
# PNEUMONIA: 8538 obrázkov

# %%
sample_paths = sorted(image_paths)[:preview_count]

if len(sample_paths) == 0:
    print("Nenašli sa žiadne obrázky.")
else:
    for image_path in sample_paths:
        original = Image.open(image_path).convert("RGB")
        processed = process_one_image(image_path)

        relative_path = image_path.relative_to(input_dir)

        print(f"Ukážka: {relative_path}")
        print(f"Originál: {original.size} | Hist. Eq. + resize: {processed.size}")

        fig, axes = plt.subplots(1, 2, figsize=(10, 4))

        axes[0].imshow(original, cmap="gray")
        axes[0].set_title("Originál")
        axes[0].axis("off")

        axes[1].imshow(processed, cmap="gray")
        axes[1].set_title("Hist. Eq. + 512×512")
        axes[1].axis("off")

        plt.tight_layout()
        plt.show()
# Out:
# Ukážka: NORMAL\IM-0001-0001.jpeg
# Originál: (1857, 1317) | Hist. Eq. + resize: (512, 512)
# Ukážka: NORMAL\IM-0001-0001_aug_1366.jpg
# Originál: (1857, 1317) | Hist. Eq. + resize: (512, 512)
# Ukážka: NORMAL\IM-0001-0001_aug_856.jpg
# Originál: (1857, 1317) | Hist. Eq. + resize: (512, 512)
# Ukážka: NORMAL\IM-0001-0001_aug_884.jpg
# Originál: (1857, 1317) | Hist. Eq. + resize: (512, 512)
# Ukážka: NORMAL\IM-0003-0001.jpeg
# Originál: (2111, 1509) | Hist. Eq. + resize: (512, 512)
# Ukážka: NORMAL\IM-0003-0001_aug_596.jpg
# Originál: (2111, 1509) | Hist. Eq. + resize: (512, 512)

# %%
processed_count = 0
skipped_count = 0
error_count = 0

total_folders = len(images_by_folder)

for folder_index, (folder_path, folder_images) in enumerate(sorted(images_by_folder.items()), start=1):
    relative_folder = folder_path.relative_to(input_dir)

    print(f"\n[{folder_index}/{total_folders}] Spracováva sa priečinok:")
    print(f"    {relative_folder}")
    print(f"    Počet obrázkov v priečinku: {len(folder_images)}")

    for image_index, image_path in enumerate(sorted(folder_images), start=1):
        try:
            relative_path = image_path.relative_to(input_dir)
            output_path = output_dir / relative_path

            if output_path.exists() and not overwrite_existing:
                skipped_count += 1
            else:
                result_img = process_one_image(image_path)
                save_image(result_img, output_path, jpeg_quality=jpeg_quality)
                processed_count += 1

            if image_index % 50 == 0 or image_index == len(folder_images):
                print(f"    Spracované v tomto priečinku: {image_index}/{len(folder_images)}")

        except Exception as e:
            error_count += 1
            print(f"    CHYBA pri obrázku: {image_path}")
            print(f"    {e}")

print("\n" + "=" * 70)
print("Hotovo.")
print(f"Celkový počet spracovaných obrázkov: {processed_count}")
print(f"Preskočené existujúce obrázky: {skipped_count}")
print(f"Počet chýb: {error_count}")
print(f"Výstupný priečinok: {output_dir}")
# Out:
# [1/2] Spracováva sa priečinok:
#     NORMAL
#     Počet obrázkov v priečinku: 5848
#     Spracované v tomto priečinku: 50/5848
#     Spracované v tomto priečinku: 100/5848
#     Spracované v tomto priečinku: 150/5848
#     Spracované v tomto priečinku: 200/5848
#     Spracované v tomto priečinku: 250/5848
#     Spracované v tomto priečinku: 300/5848
#     Spracované v tomto priečinku: 350/5848
#     Spracované v tomto priečinku: 400/5848
#     Spracované v tomto priečinku: 450/5848
#     Spracované v tomto priečinku: 500/5848
#     Spracované v tomto priečinku: 550/5848
#     Spracované v tomto priečinku: 600/5848
#     Spracované v tomto priečinku: 650/5848
#     Spracované v tomto priečinku: 700/5848
#     Spracované v tomto priečinku: 750/5848
#     Spracované v tomto priečinku: 800/5848
#     Spracované v tomto priečinku: 850/5848
#     Spracované v tomto priečinku: 900/5848
#     Spracované v tomto priečinku: 950/5848
#     Spracované v tomto priečinku: 1000/5848
#     Spracované v tomto priečinku: 1050/5848
#     Spracované v tomto priečinku: 1100/5848
#     Spracované v tomto priečinku: 1150/5848
#     Spracované v tomto priečinku: 1200/5848
#     Spracované v tomto priečinku: 1250/5848
#     Spracované v tomto priečinku: 1300/5848
#     Spracované v tomto priečinku: 1350/5848
#     Spracované v tomto priečinku: 1400/5848
#     Spracované v tomto priečinku: 1450/5848
#     Spracované v tomto priečinku: 1500/5848
#     Spracované v tomto priečinku: 1550/5848
#     Spracované v tomto priečinku: 1600/5848
#     Spracované v tomto priečinku: 1650/5848
#     Spracované v tomto priečinku: 1700/5848
#     Spracované v tomto priečinku: 1750/5848
#     Spracované v tomto priečinku: 1800/5848
#     Spracované v tomto priečinku: 1850/5848
#     Spracované v tomto priečinku: 1900/5848
#     Spracované v tomto priečinku: 1950/5848
#     Spracované v tomto priečinku: 2000/5848
#     Spracované v tomto priečinku: 2050/5848
#     Spracované v tomto priečinku: 2100/5848
#     Spracované v tomto priečinku: 2150/5848
#     Spracované v tomto priečinku: 2200/5848
#     Spracované v tomto priečinku: 2250/5848
#     Spracované v tomto priečinku: 2300/5848
#     Spracované v tomto priečinku: 2350/5848
#     Spracované v tomto priečinku: 2400/5848
#     Spracované v tomto priečinku: 2450/5848
#     Spracované v tomto priečinku: 2500/5848
#     Spracované v tomto priečinku: 2550/5848
#     Spracované v tomto priečinku: 2600/5848
#     Spracované v tomto priečinku: 2650/5848
#     Spracované v tomto priečinku: 2700/5848
#     Spracované v tomto priečinku: 2750/5848
#     Spracované v tomto priečinku: 2800/5848
#     Spracované v tomto priečinku: 2850/5848
#     Spracované v tomto priečinku: 2900/5848
#     Spracované v tomto priečinku: 2950/5848
#     Spracované v tomto priečinku: 3000/5848
#     Spracované v tomto priečinku: 3050/5848
#     Spracované v tomto priečinku: 3100/5848
#     Spracované v tomto priečinku: 3150/5848
#     Spracované v tomto priečinku: 3200/5848
#     Spracované v tomto priečinku: 3250/5848
#     Spracované v tomto priečinku: 3300/5848
#     Spracované v tomto priečinku: 3350/5848
#     Spracované v tomto priečinku: 3400/5848
#     Spracované v tomto priečinku: 3450/5848
#     Spracované v tomto priečinku: 3500/5848
#     Spracované v tomto priečinku: 3550/5848
#     Spracované v tomto priečinku: 3600/5848
#     Spracované v tomto priečinku: 3650/5848
#     Spracované v tomto priečinku: 3700/5848
#     Spracované v tomto priečinku: 3750/5848
#     Spracované v tomto priečinku: 3800/5848
#     Spracované v tomto priečinku: 3850/5848
#     Spracované v tomto priečinku: 3900/5848
#     Spracované v tomto priečinku: 3950/5848
#     Spracované v tomto priečinku: 4000/5848
#     Spracované v tomto priečinku: 4050/5848
#     Spracované v tomto priečinku: 4100/5848
#     Spracované v tomto priečinku: 4150/5848
#     Spracované v tomto priečinku: 4200/5848
#     Spracované v tomto priečinku: 4250/5848
#     Spracované v tomto priečinku: 4300/5848
#     Spracované v tomto priečinku: 4350/5848
#     Spracované v tomto priečinku: 4400/5848
#     Spracované v tomto priečinku: 4450/5848
#     Spracované v tomto priečinku: 4500/5848
#     Spracované v tomto priečinku: 4550/5848
#     Spracované v tomto priečinku: 4600/5848
#     Spracované v tomto priečinku: 4650/5848
#     Spracované v tomto priečinku: 4700/5848
#     Spracované v tomto priečinku: 4750/5848
#     Spracované v tomto priečinku: 4800/5848
#     Spracované v tomto priečinku: 4850/5848
#     Spracované v tomto priečinku: 4900/5848
#     Spracované v tomto priečinku: 4950/5848
#     Spracované v tomto priečinku: 5000/5848
#     Spracované v tomto priečinku: 5050/5848
#     Spracované v tomto priečinku: 5100/5848
#     Spracované v tomto priečinku: 5150/5848
#     Spracované v tomto priečinku: 5200/5848
#     Spracované v tomto priečinku: 5250/5848
#     Spracované v tomto priečinku: 5300/5848
#     Spracované v tomto priečinku: 5350/5848
#     Spracované v tomto priečinku: 5400/5848
#     Spracované v tomto priečinku: 5450/5848
#     Spracované v tomto priečinku: 5500/5848
#     Spracované v tomto priečinku: 5550/5848
#     Spracované v tomto priečinku: 5600/5848
#     Spracované v tomto priečinku: 5650/5848
#     Spracované v tomto priečinku: 5700/5848
#     Spracované v tomto priečinku: 5750/5848
#     Spracované v tomto priečinku: 5800/5848
#     Spracované v tomto priečinku: 5848/5848
#
# [2/2] Spracováva sa priečinok:
#     PNEUMONIA
#     Počet obrázkov v priečinku: 8538
#     Spracované v tomto priečinku: 50/8538
#     Spracované v tomto priečinku: 100/8538
#     Spracované v tomto priečinku: 150/8538
#     Spracované v tomto priečinku: 200/8538
#     Spracované v tomto priečinku: 250/8538
#     Spracované v tomto priečinku: 300/8538
#     Spracované v tomto priečinku: 350/8538
#     Spracované v tomto priečinku: 400/8538
#     Spracované v tomto priečinku: 450/8538
#     Spracované v tomto priečinku: 500/8538
#     Spracované v tomto priečinku: 550/8538
#     Spracované v tomto priečinku: 600/8538
#     Spracované v tomto priečinku: 650/8538
#     Spracované v tomto priečinku: 700/8538
#     Spracované v tomto priečinku: 750/8538
#     Spracované v tomto priečinku: 800/8538
#     Spracované v tomto priečinku: 850/8538
#     Spracované v tomto priečinku: 900/8538
#     Spracované v tomto priečinku: 950/8538
#     Spracované v tomto priečinku: 1000/8538
#     Spracované v tomto priečinku: 1050/8538
#     Spracované v tomto priečinku: 1100/8538
#     Spracované v tomto priečinku: 1150/8538
#     Spracované v tomto priečinku: 1200/8538
#     Spracované v tomto priečinku: 1250/8538
#     Spracované v tomto priečinku: 1300/8538
#     Spracované v tomto priečinku: 1350/8538
#     Spracované v tomto priečinku: 1400/8538
#     Spracované v tomto priečinku: 1450/8538
#     Spracované v tomto priečinku: 1500/8538
#     Spracované v tomto priečinku: 1550/8538
#     Spracované v tomto priečinku: 1600/8538
#     Spracované v tomto priečinku: 1650/8538
#     Spracované v tomto priečinku: 1700/8538
#     Spracované v tomto priečinku: 1750/8538
#     Spracované v tomto priečinku: 1800/8538
#     Spracované v tomto priečinku: 1850/8538
#     Spracované v tomto priečinku: 1900/8538
#     Spracované v tomto priečinku: 1950/8538
#     Spracované v tomto priečinku: 2000/8538
#     Spracované v tomto priečinku: 2050/8538
#     Spracované v tomto priečinku: 2100/8538
#     Spracované v tomto priečinku: 2150/8538
#     Spracované v tomto priečinku: 2200/8538
#     Spracované v tomto priečinku: 2250/8538
#     Spracované v tomto priečinku: 2300/8538
#     Spracované v tomto priečinku: 2350/8538
#     Spracované v tomto priečinku: 2400/8538
#     Spracované v tomto priečinku: 2450/8538
#     Spracované v tomto priečinku: 2500/8538
#     Spracované v tomto priečinku: 2550/8538
#     Spracované v tomto priečinku: 2600/8538
#     Spracované v tomto priečinku: 2650/8538
#     Spracované v tomto priečinku: 2700/8538
#     Spracované v tomto priečinku: 2750/8538
#     Spracované v tomto priečinku: 2800/8538
#     Spracované v tomto priečinku: 2850/8538
#     Spracované v tomto priečinku: 2900/8538
#     Spracované v tomto priečinku: 2950/8538
#     Spracované v tomto priečinku: 3000/8538
#     Spracované v tomto priečinku: 3050/8538
#     Spracované v tomto priečinku: 3100/8538
#     Spracované v tomto priečinku: 3150/8538
#     Spracované v tomto priečinku: 3200/8538
#     Spracované v tomto priečinku: 3250/8538
#     Spracované v tomto priečinku: 3300/8538
#     Spracované v tomto priečinku: 3350/8538
#     Spracované v tomto priečinku: 3400/8538
#     Spracované v tomto priečinku: 3450/8538
#     Spracované v tomto priečinku: 3500/8538
#     Spracované v tomto priečinku: 3550/8538
#     Spracované v tomto priečinku: 3600/8538
#     Spracované v tomto priečinku: 3650/8538
#     Spracované v tomto priečinku: 3700/8538
#     Spracované v tomto priečinku: 3750/8538
#     Spracované v tomto priečinku: 3800/8538
#     Spracované v tomto priečinku: 3850/8538
#     Spracované v tomto priečinku: 3900/8538
#     Spracované v tomto priečinku: 3950/8538
#     Spracované v tomto priečinku: 4000/8538
#     Spracované v tomto priečinku: 4050/8538
#     Spracované v tomto priečinku: 4100/8538
#     Spracované v tomto priečinku: 4150/8538
#     Spracované v tomto priečinku: 4200/8538
#     Spracované v tomto priečinku: 4250/8538
#     Spracované v tomto priečinku: 4300/8538
#     Spracované v tomto priečinku: 4350/8538
#     Spracované v tomto priečinku: 4400/8538
#     Spracované v tomto priečinku: 4450/8538
#     Spracované v tomto priečinku: 4500/8538
#     Spracované v tomto priečinku: 4550/8538
#     Spracované v tomto priečinku: 4600/8538
#     Spracované v tomto priečinku: 4650/8538
#     Spracované v tomto priečinku: 4700/8538
#     Spracované v tomto priečinku: 4750/8538
#     Spracované v tomto priečinku: 4800/8538
#     Spracované v tomto priečinku: 4850/8538
#     Spracované v tomto priečinku: 4900/8538
#     Spracované v tomto priečinku: 4950/8538
#     Spracované v tomto priečinku: 5000/8538
#     Spracované v tomto priečinku: 5050/8538
#     Spracované v tomto priečinku: 5100/8538
#     Spracované v tomto priečinku: 5150/8538
#     Spracované v tomto priečinku: 5200/8538
#     Spracované v tomto priečinku: 5250/8538
#     Spracované v tomto priečinku: 5300/8538
#     Spracované v tomto priečinku: 5350/8538
#     Spracované v tomto priečinku: 5400/8538
#     Spracované v tomto priečinku: 5450/8538
#     Spracované v tomto priečinku: 5500/8538
#     Spracované v tomto priečinku: 5550/8538
#     Spracované v tomto priečinku: 5600/8538
#     Spracované v tomto priečinku: 5650/8538
#     Spracované v tomto priečinku: 5700/8538
#     Spracované v tomto priečinku: 5750/8538
#     Spracované v tomto priečinku: 5800/8538
#     Spracované v tomto priečinku: 5850/8538
#     Spracované v tomto priečinku: 5900/8538
#     Spracované v tomto priečinku: 5950/8538
#     Spracované v tomto priečinku: 6000/8538
#     Spracované v tomto priečinku: 6050/8538
#     Spracované v tomto priečinku: 6100/8538
#     Spracované v tomto priečinku: 6150/8538
#     Spracované v tomto priečinku: 6200/8538
#     Spracované v tomto priečinku: 6250/8538
#     Spracované v tomto priečinku: 6300/8538
#     Spracované v tomto priečinku: 6350/8538
#     Spracované v tomto priečinku: 6400/8538
#     Spracované v tomto priečinku: 6450/8538
#     Spracované v tomto priečinku: 6500/8538
#     Spracované v tomto priečinku: 6550/8538
#     Spracované v tomto priečinku: 6600/8538
#     Spracované v tomto priečinku: 6650/8538
#     Spracované v tomto priečinku: 6700/8538
#     Spracované v tomto priečinku: 6750/8538
#     Spracované v tomto priečinku: 6800/8538
#     Spracované v tomto priečinku: 6850/8538
#     Spracované v tomto priečinku: 6900/8538
#     Spracované v tomto priečinku: 6950/8538
#     Spracované v tomto priečinku: 7000/8538
#     Spracované v tomto priečinku: 7050/8538
#     Spracované v tomto priečinku: 7100/8538
#     Spracované v tomto priečinku: 7150/8538
#     Spracované v tomto priečinku: 7200/8538
#     Spracované v tomto priečinku: 7250/8538
#     Spracované v tomto priečinku: 7300/8538
#     Spracované v tomto priečinku: 7350/8538
#     Spracované v tomto priečinku: 7400/8538
#     Spracované v tomto priečinku: 7450/8538
#     Spracované v tomto priečinku: 7500/8538
#     Spracované v tomto priečinku: 7550/8538
#     Spracované v tomto priečinku: 7600/8538
#     Spracované v tomto priečinku: 7650/8538
#     Spracované v tomto priečinku: 7700/8538
#     Spracované v tomto priečinku: 7750/8538
#     Spracované v tomto priečinku: 7800/8538
#     Spracované v tomto priečinku: 7850/8538
#     Spracované v tomto priečinku: 7900/8538
#     Spracované v tomto priečinku: 7950/8538
#     Spracované v tomto priečinku: 8000/8538
#     Spracované v tomto priečinku: 8050/8538
#     Spracované v tomto priečinku: 8100/8538
#     Spracované v tomto priečinku: 8150/8538
#     Spracované v tomto priečinku: 8200/8538
#     Spracované v tomto priečinku: 8250/8538
#     Spracované v tomto priečinku: 8300/8538
#     Spracované v tomto priečinku: 8350/8538
#     Spracované v tomto priečinku: 8400/8538
#     Spracované v tomto priečinku: 8450/8538
#     Spracované v tomto priečinku: 8500/8538
#     Spracované v tomto priečinku: 8538/8538
#
# ======================================================================
# Hotovo.
# Celkový počet spracovaných obrázkov: 14386
# Preskočené existujúce obrázky: 0
# Počet chýb: 0
# Výstupný priečinok: D:\hsu_semestralka\dataset_merged_histogram_equalization_512

# %%
output_image_paths = [
    path for path in output_dir.rglob("*")
    if path.is_file() and path.suffix.lower() in valid_extensions
]

print(f"Počet vstupných obrázkov: {len(image_paths)}")
print(f"Počet výstupných obrázkov: {len(output_image_paths)}")

if len(image_paths) == len(output_image_paths):
    print("Počty sedia.")
else:
    print("Počty nesedia. Skontroluj logy a prípadné chyby.")
# Out:
# Počet vstupných obrázkov: 14386
# Počet výstupných obrázkov: 14386
# Počty sedia.
